# %% [markdown]
# CE080_Vedant_Parikh
#
# Machine Learning
#
# Lab : 04

# %% [markdown]
# ### ***Linear regression model from scratch***

# %%
import numpy as np
import torch

# %%
inputs = np.array([[73, 67, 43],
[91, 88, 64],
[87, 134, 58],
[102, 43, 37],
[69, 96, 70]], dtype='float32')

# %%
targets = np.array([[56],
[81],
[119],
[22],
[103]], dtype='float32')

# %%
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)

# %%
weight = torch.randn(2, 3, requires_grad=True)
bias = torch.randn(2, requires_grad=True)

# %%
inputs @ weight.t() + bias
# Out:
# tensor([[-198.6156,  -26.7580],
#         [-271.4157,  -20.7641],
#         [-276.0429,  -30.9838],
#         [-206.0426,  -60.4041],
#         [-264.0466,    8.0755]], grad_fn=<AddBackward0>)

# %%
def model(inputs):
    return inputs @ weight.t() + bias

# %%
prediction = model(inputs)
print(prediction)
# Out:
# tensor([[-198.6156,  -26.7580],
#         [-271.4157,  -20.7641],
#         [-276.0429,  -30.9838],
#         [-206.0426,  -60.4041],
#         [-264.0466,    8.0755]], grad_fn=<AddBackward0>)

# %% [markdown]
# ### ***Loss function***

# %%
diff0 = prediction - targets
torch.sum(diff0 * diff0) / diff0.numel()
# Out:
# tensor(58731.2578, grad_fn=<DivBackward0>)

# %%
def mse(t1, t2):
    diff = t1 - t2
    return torch.sum(diff * diff) / diff.numel()

# %%
loss = mse(prediction, targets)
print(loss)
# Out:
# tensor(58731.2578, grad_fn=<DivBackward0>)

# %% [markdown]
# ### ***Compute gradients***

# %%
loss.backward()
print(weight.grad)
print(bias.grad)
# Out:
# tensor([[-26722.4141, -29209.9785, -18109.2812],
#         [ -8661.0938,  -9450.7969,  -5692.8452]])
# tensor([-319.4327, -102.3669])

# %% [markdown]
# ### ***Train the model using gradient descent***

# %%
with torch.no_grad():
    weight -= weight.grad * 1e-5
    bias -= bias.grad * 1e-5
    weight.grad.zero_()
    bias.grad.zero_()

# %%
prediction = model(inputs)
loss = mse(prediction, targets)
print(loss)
# Out:
# tensor(39683.4453, grad_fn=<DivBackward0>)

# %%
for i in range(100):
    prediction = model(inputs)
    loss = mse(prediction, targets)
    loss.backward()
    with torch.no_grad():
        weight -= weight.grad * 1e-5
        bias -= bias.grad * 1e-5
        weight.grad.zero_()
        bias.grad.zero_()

# %%
prediction = model(inputs)
loss = mse(prediction, targets)
print(loss)
# Out:
# tensor(212.0650, grad_fn=<DivBackward0>)

# %%
prediction
# Out:
# tensor([[ 60.9882,  57.1441],
#         [ 72.2041,  89.0405],
#         [135.2977, 103.1879],
#         [ 41.6574,  20.8080],
#         [ 72.5878, 114.1388]], grad_fn=<AddBackward0>)

# %%
targets
# Out:
# tensor([[ 56.],
#         [ 81.],
#         [119.],
#         [ 22.],
#         [103.]])
